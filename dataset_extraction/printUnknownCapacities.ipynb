# %% [markdown]
# # Prints the names of all the cables with unknown capacity

# %%
import networkx as nx

G = nx.read_graphml("THE_GRAPH.graphml")
print(G)
# Out:
# Graph with 1031 nodes and 1279 edges

# %%
cableNames = set()
for e in G.edges(data=True):
    data = e[2]#get the data part of the edge
    if data["capacity"] == 0:
        cableNames.add(data["name"])
        
print(len(cableNames))
for c in cableNames:
    print(c)
# Out:
# 154
# TAGIDE-2
# SEAK
# Trinidad-Curaco
# SMPR-1
# ASH (American Samoa - Hawaii)
# Mid-Atlantic Crossing (MAC)
# Russia-Japan Cable Network (RJCN)
# Australia-Singapore Cable
# Tata Indicom (TIISCS)
# CC5
# Arctic Fibre
# Tasman Global Access
# Telstra Bass Strait 2
# NorthStar
# COLUMBUS II
# PPC-1
# Alaska United - West
# BAHAMAS-2
# AAE-1 (Asia Africa Europe)
# Far East Submarine Cable System
# ALETAR
# America Movil-1
# Loukkos
# MCT Cable System
# CUCN
# SAS (Samoa - American Samoa)
# Med Cable
# CeltixConnect
# Qatar-UAE Submarine Cable System
# JONAH
# LANIS 2
# Flores-Covo Cable System
# LANIS 1
# Melita-1
# Telstra Bass Strait 1
# TSE-1
# SEA-ME-WE-4
# Estepona-Tetuan
# Trapani-Kelibia (KELTRA-2)
# HONOTUA International
# BT-MT1
# FLAG Europe Asia (FEA)
# GLO1
# Thailand-Indonesia-Singapore (TIS)
# CanaLink
# TE North
# AEConnect
# Tata TGN Intra-Asia (TGN-IA)
# MainOne
# CORSAR (Corsica- Sardinia)
# WASACE
# FLAG North Asia Loop (FNAL)
# LIME
# Sirius North
# BP Fiber Backbone
# LION
# NorSea Com 1
# HONOTUA Domestic
# Pangea Baltic Loop
# Pan-American Crossing (PAC)
# Hokkaido-Sakhalin Cable System (HSCS)
# HAWK
# TEAMs
# Finland-Sweden 4 (SFS-4)
# TGN Western Europe
# Southern Cross
# Alaska United - East
# Sweden-Finland Link (SFL)
# ROTACS
# APX East
# Americas II
# TGN Transpacific
# Basslink Telecom
# COLUMBUS III
# Cayman-Jamaica
# Transworld (TWA-1)
# APX West
# Seabras-1
# South American Crossing (SAC
# SAex
# Dumai-Melaka
# SEAS
# WARF
# AAG (Asia-American Gateway)
# ULYSSES
# SJC
# TPC-5CN
# Islalink
# Moratelindo Batam Dumai Cable (MBDC)
# Korea-Japan Cable Network (KJCN)
# Matrix cable system
# Tamares Telecom
# TGN Atlantic
# RIOJA-3
# SLT-Dhiraagu
# TURMEOS-1
# Hawaiki
# Emerald Bridge Fibres
# PCCS
# BBG (Bay of Bengal Gateway)
# EASSY
# Alexandros
# EESF-2 (Finland-Estonia 2)
# APG (Asia-Pacific Gateway)
# FLAG ATLANTIC NORTH
# Kodiak Kenai
# Thailand-Vietnam-Hong Kong (T-V-H)
# Kategat-1
# Pishgaman Oman Iran (POI)
# ADRIA-1
# BDNSi
# SEA-ME-WE-5
# Global Carribean Network (GCN)
# Fehmarn Belt
# Sirius South
# BRICS Cable
# Trans-Pacific Express
# Japan-US
# Suriname-Guyana (SG-SCS)
# HANTRU-1
# FLAG Atlantic (FA-1)
# RNAL
# PAN AM
# C-Lion
# Trident
# ULYSSES 2
# Tonga-Fiji
# SAT-3
# Svalbard Undersea Cable System
# Challenger
# TURCYOS-2
# Hibernia Express
# UK-Channel Isles 7
# Ariane 2
# Vanuatu-Fiji Interchange Cable Network
# TGN-Gulf
# APHRODITE-2
# MENA
# EESF-3 (Finland--Estonia 3)
# FOG (Fibre Optic Gulf)
# MONET
# SACS
# Silphium
# CIRCE North
# AKORN Alaska-Oregon
# Corfu-Bar
# TURCYOS-1
# I-ME-WE
# Gulf Bridge International
# KINYRAS
# Pencan-6
# LION2
# Moana
# Asia-Submarine Express (ASE)
